# %% [markdown]
# <a href="https://colab.research.google.com/github/JonathaVaz/Criando-Gr-ficos-em-Python-Visualiza-o-de-Dados-/blob/main/Gr%C3%A1fico_de_Histograma.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Criando Gráfico de Histograma com o Matplotlib
# Autor: Jonatha Rodrigues Tenorio Vaz
# Data: 10/04/2023

# %%
# Importando as Bibliotecas

import numpy as np
import matplotlib.pyplot as plt

# %%
# Criando variável X com números aleatórios 

X = np.random.rand(2000)

# %%
# Criando Histograma (Gráfico)

plt.hist(X)
plt.xlabel('X')
plt.ylabel('Contagem')
plt.show()

# %%
# Alterando número de bins

plt.hist(X,bins=10)
plt.xlabel('X')
plt.ylabel('Contagem')
plt.title('Bins=10')
plt.show()

# %%
# Alterando a largura do Gráfico para uma melhor Visualização

plt.hist(X,bins=20)
plt.xlabel('X')
plt.ylabel('Contagem')
plt.title('Bins=20')
plt.show()

# %%
plt.hist(X,bins=30)
plt.xlabel('X')
plt.ylabel('Contagem')
plt.title('Bins=30')
plt.show()

# %%
# Alterando as Cores 

plt.hist(X,bins=50,color='magenta')
plt.xlabel('X')
plt.ylabel('Contagem')
plt.title('Bins=50')
plt.show()

# %%
plt.hist(X,bins=50,color='beige')
plt.xlabel('X')
plt.ylabel('Contagem')
plt.title('Bins=50')
plt.show()

# %%
plt.hist(X,bins=50,color='turquoise')
plt.xlabel('X')
plt.ylabel('Contagem')
plt.title('Bins=50')
plt.show()

# %%
# Criando as entrelinhas das barras do Histograma

plt.hist(X,bins=50,color='turquoise', edgecolor='black')
plt.xlabel('X')
plt.ylabel('Contagem')
plt.title('Bins=50')
plt.show()

# %%
# Multiplos Histogramas na mesma Imagem

X1 = np.random.normal(0,1,size = 800)
X2 = np.random.normal(3,1,size = 800)
X3 = np.random.normal(5,1,size = 800)

# %%
# Criando o Gráfico

plt.hist(X1,bins=10,color='violet')
plt.hist(X2,bins=10,color='magenta')
plt.hist(X3,bins=10,color='purple')
plt.xlabel('X')
plt.ylabel('Contagem')
plt.title('Multiplos histogramas')
plt.show()

# %%
# Distribuição cumulativa

X = np.random.random(2000)

# %%
# Criando o Gráfico

plt.hist(X,bins=20,color='turquoise', edgecolor='black',cumulative=True)
plt.xlabel('X')
plt.ylabel('Contagem')
plt.title('Histograma cumulativo')
plt.show()
